# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.2.10-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.2.10-py2.py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.2.10

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import json
import time
import random
import threading
import queue
import datetime

# %%
# Configuration
SOURCE_FILE = "/content/drive/MyDrive/SmartFactory/Dataset/factory_sensor_data.json"
BATCH_SIZE = 10
STREAM_INTERVAL = 1
ENABLE_ANOMALY = True
USE_KAFKA = False  # Set to True when integrating Kafka later

# %%
# Load historical sensor data
with open(SOURCE_FILE, 'r') as f:
    sensor_data = json.load(f)

# %%
# Queue to simulate streaming pipeline
data_queue = queue.Queue()
stream_manifest = []

# %%
def inject_anomalies(record):
    """Randomly inject small anomalies for simulation."""
    anomaly_chance = 0.05
    if random.random() < anomaly_chance:
        record["vibration"] *= random.uniform(1.5, 3.0)
        record["failure"] = 1  # force failure label
        record["note"] = "anomaly_injected"
    return record

# %%
def data_streamer():
    """Simulates real-time IoT streaming."""
    idx = 0
    while idx < len(sensor_data):
        batch = sensor_data[idx:idx + BATCH_SIZE]
        for record in batch:
            record["timestamp"] = datetime.datetime.now().isoformat()
            if ENABLE_ANOMALY:
                record = inject_anomalies(record)
            data_queue.put(record)
        idx += BATCH_SIZE
        time.sleep(STREAM_INTERVAL)

# %%
def file_data_ingestor():
    """Ingest data from stream and write JSON files."""
    buffer = []
    file_index = 0
    total_records = 0

    while True:
        try:
            record = data_queue.get(timeout=10)
            buffer.append(record)

            if len(buffer) >= BATCH_SIZE:
                filename = f"/content/drive/MyDrive/SmartFactory/Results/Week5/StreamBatch/stream_batch_{file_index}.json"
                with open(filename, 'w') as f_out:
                    json.dump(buffer, f_out, indent=2)
                stream_manifest.append({
                    "batch_file": filename,
                    "records": len(buffer),
                    "timestamp": datetime.datetime.now().isoformat()
                })
                print(f"[SAVED] Batch {file_index} | Records: {len(buffer)}")
                total_records += len(buffer)
                buffer.clear()
                file_index += 1

        except queue.Empty:
            print(f"[INFO] Ingestion complete. Total records saved: {total_records}")
            break

    # Save manifest
    with open(f"/content/drive/MyDrive/SmartFactory/Results/Week5/stream_manifest.json", 'w') as f_manifest:
        json.dump(stream_manifest, f_manifest, indent=2)
    print(f"[MANIFEST] Created: stream_manifest.json")

# %%
def kafka_data_ingestor():
    """Placeholder for Kafka integration (extend later)."""
    from kafka import KafkaProducer
    producer = KafkaProducer(
        bootstrap_servers='localhost:9092',
        value_serializer=lambda v: json.dumps(v).encode('utf-8')
    )
    topic = "smartfactory-stream"

    total_sent = 0
    while True:
        try:
            record = data_queue.get(timeout=10)
            producer.send(topic, record)
            total_sent += 1
            if total_sent % 100 == 0:
                print(f"[KAFKA] Total messages sent: {total_sent}")
        except queue.Empty:
            print(f"[KAFKA] Streaming complete. Total messages sent: {total_sent}")
            break
    producer.flush()

# %%
# Setup streamer and appropriate ingestor
stream_thread = threading.Thread(target=data_streamer)
ingest_thread = threading.Thread(
    target=kafka_data_ingestor if USE_KAFKA else file_data_ingestor
)

stream_thread.start()
ingest_thread.start()

stream_thread.join()
ingest_thread.join()

print("Extended streaming simulation complete.")
# Out:
# [SAVED] Batch 0 | Records: 10
# [SAVED] Batch 1 | Records: 10
# [SAVED] Batch 2 | Records: 10
# [SAVED] Batch 3 | Records: 10
# [SAVED] Batch 4 | Records: 10
# [SAVED] Batch 5 | Records: 10
# [SAVED] Batch 6 | Records: 10
# [SAVED] Batch 7 | Records: 10
# [SAVED] Batch 8 | Records: 10
# [SAVED] Batch 9 | Records: 10
# [SAVED] Batch 10 | Records: 10
# [SAVED] Batch 11 | Records: 10
# [SAVED] Batch 12 | Records: 10
# [SAVED] Batch 13 | Records: 10
# [SAVED] Batch 14 | Records: 10
# [SAVED] Batch 15 | Records: 10
# [SAVED] Batch 16 | Records: 10
# [SAVED] Batch 17 | Records: 10
# [SAVED] Batch 18 | Records: 10
# [SAVED] Batch 19 | Records: 10
# [SAVED] Batch 20 | Records: 10
# [SAVED] Batch 21 | Records: 10
# [SAVED] Batch 22 | Records: 10
# [SAVED] Batch 23 | Records: 10
# [SAVED] Batch 24 | Records: 10
# [SAVED] Batch 25 | Records: 10
# [SAVED] Batch 26 | Records: 10
# [SAVED] Batch 27 | Records: 10
# [SAVED] Batch 28 | Records: 10
# [SAVED] Batch 29 | Records: 10
# [SAVED] Batch 30 | Records: 10
# [SAVED] Batch 31 | Records: 10
# [SAVED] Batch 32 | Records: 10
# [SAVED] Batch 33 | Records: 10
# [SAVED] Batch 34 | Records: 10
# [SAVED] Batch 35 | Records: 10
# [SAVED] Batch 36 | Records: 10
# [SAVED] Batch 37 | Records: 10
# [SAVED] Batch 38 | Records: 10
# [SAVED] Batch 39 | Records: 10
# [SAVED] Batch 40 | Records: 10
# [SAVED] Batch 41 | Records: 10
# [SAVED] Batch 42 | Records: 10
# [SAVED] Batch 43 | Records: 10
# [SAVED] Batch 44 | Records: 10
# [SAVED] Batch 45 | Records: 10
# [SAVED] Batch 46 | Records: 10
# [SAVED] Batch 47 | Records: 10
# [SAVED] Batch 48 | Records: 10
# [SAVED] Batch 49 | Records: 10
# [SAVED] Batch 50 | Records: 10
# [SAVED] Batch 51 | Records: 10
# [SAVED] Batch 52 | Records: 10
# [SAVED] Batch 53 | Records: 10
# [SAVED] Batch 54 | Records: 10
# [SAVED] Batch 55 | Records: 10
# [SAVED] Batch 56 | Records: 10
# [SAVED] Batch 57 | Records: 10
# [SAVED] Batch 58 | Records: 10
# [SAVED] Batch 59 | Records: 10
# [SAVED] Batch 60 | Records: 10
# [SAVED] Batch 61 | Records: 10
# [SAVED] Batch 62 | Records: 10
# [SAVED] Batch 63 | Records: 10
# [SAVED] Batch 64 | Records: 10
# [SAVED] Batch 65 | Records: 10
# [SAVED] Batch 66 | Records: 10
# [SAVED] Batch 67 | Records: 10
# [SAVED] Batch 68 | Records: 10
# [SAVED] Batch 69 | Records: 10
# [SAVED] Batch 70 | Records: 10
# [SAVED] Batch 71 | Records: 10
# [SAVED] Batch 72 | Records: 10
# [SAVED] Batch 73 | Records: 10
# [SAVED] Batch 74 | Records: 10
# [SAVED] Batch 75 | Records: 10
# [SAVED] Batch 76 | Records: 10
# [SAVED] Batch 77 | Records: 10
# [SAVED] Batch 78 | Records: 10
# [SAVED] Batch 79 | Records: 10
# [SAVED] Batch 80 | Records: 10
# [SAVED] Batch 81 | Records: 10
# [SAVED] Batch 82 | Records: 10
# [SAVED] Batch 83 | Records: 10
# [SAVED] Batch 84 | Records: 10
# [SAVED] Batch 85 | Records: 10
# [SAVED] Batch 86 | Records: 10
# [SAVED] Batch 87 | Records: 10
# [SAVED] Batch 88 | Records: 10
# [SAVED] Batch 89 | Records: 10
# [SAVED] Batch 90 | Records: 10
# [SAVED] Batch 91 | Records: 10
# [SAVED] Batch 92 | Records: 10
# [SAVED] Batch 93 | Records: 10
# [SAVED] Batch 94 | Records: 10
# [SAVED] Batch 95 | Records: 10
# [SAVED] Batch 96 | Records: 10
# [SAVED] Batch 97 | Records: 10
# [SAVED] Batch 98 | Records: 10
# [SAVED] Batch 99 | Records: 10
# [SAVED] Batch 100 | Records: 10
# [SAVED] Batch 101 | Records: 10
# [SAVED] Batch 102 | Records: 10
# [SAVED] Batch 103 | Records: 10
# [SAVED] Batch 104 | Records: 10
# [SAVED] Batch 105 | Records: 10
# [SAVED] Batch 106 | Records: 10
# [SAVED] Batch 107 | Records: 10
# [SAVED] Batch 108 | Records: 10
# [SAVED] Batch 109 | Records: 10
# [SAVED] Batch 110 | Records: 10
# [SAVED] Batch 111 | Records: 10
# [SAVED] Batch 112 | Records: 10
# [SAVED] Batch 113 | Records: 10
# [SAVED] Batch 114 | Records: 10
# [SAVED] Batch 115 | Records: 10
# [SAVED] Batch 116 | Records: 10
# [SAVED] Batch 117 | Records: 10
# [SAVED] Batch 118 | Records: 10
# [SAVED] Batch 119 | Records: 10
# [SAVED] Batch 120 | Records: 10
# [SAVED] Batch 121 | Records: 10
# [SAVED] Batch 122 | Records: 10
# [SAVED] Batch 123 | Records: 10
# [SAVED] Batch 124 | Records: 10
# [SAVED] Batch 125 | Records: 10
# [SAVED] Batch 126 | Records: 10
# [SAVED] Batch 127 | Records: 10
# [SAVED] Batch 128 | Records: 10
# [SAVED] Batch 129 | Records: 10
# [SAVED] Batch 130 | Records: 10
# [SAVED] Batch 131 | Records: 10
# [SAVED] Batch 132 | Records: 10
# [SAVED] Batch 133 | Records: 10
# [SAVED] Batch 134 | Records: 10
# [SAVED] Batch 135 | Records: 10
# [SAVED] Batch 136 | Records: 10
# [SAVED] Batch 137 | Records: 10
# [SAVED] Batch 138 | Records: 10
# [SAVED] Batch 139 | Records: 10
# [SAVED] Batch 140 | Records: 10
# [SAVED] Batch 141 | Records: 10
# [SAVED] Batch 142 | Records: 10
# [SAVED] Batch 143 | Records: 10
# [SAVED] Batch 144 | Records: 10
# [SAVED] Batch 145 | Records: 10
# [SAVED] Batch 146 | Records: 10
# [SAVED] Batch 147 | Records: 10
# [SAVED] Batch 148 | Records: 10
# [SAVED] Batch 149 | Records: 10
# [SAVED] Batch 150 | Records: 10
# [SAVED] Batch 151 | Records: 10
# [SAVED] Batch 152 | Records: 10
# [SAVED] Batch 153 | Records: 10
# [SAVED] Batch 154 | Records: 10
# [SAVED] Batch 155 | Records: 10
# [SAVED] Batch 156 | Records: 10
# [SAVED] Batch 157 | Records: 10
# [SAVED] Batch 158 | Records: 10
# [SAVED] Batch 159 | Records: 10
# [SAVED] Batch 160 | Records: 10
# [SAVED] Batch 161 | Records: 10
# [SAVED] Batch 162 | Records: 10
# [SAVED] Batch 163 | Records: 10
# [SAVED] Batch 164 | Records: 10
# [SAVED] Batch 165 | Records: 10
# [SAVED] Batch 166 | Records: 10
# [SAVED] Batch 167 | Records: 10
# [SAVED] Batch 168 | Records: 10
# [SAVED] Batch 169 | Records: 10
# [SAVED] Batch 170 | Records: 10
# [SAVED] Batch 171 | Records: 10
# [SAVED] Batch 172 | Records: 10
# [SAVED] Batch 173 | Records: 10
# [SAVED] Batch 174 | Records: 10
# [SAVED] Batch 175 | Records: 10
# [SAVED] Batch 176 | Records: 10
# [SAVED] Batch 177 | Records: 10
# [SAVED] Batch 178 | Records: 10
# [SAVED] Batch 179 | Records: 10
# [SAVED] Batch 180 | Records: 10
# [SAVED] Batch 181 | Records: 10
# [SAVED] Batch 182 | Records: 10
# [SAVED] Batch 183 | Records: 10
# [SAVED] Batch 184 | Records: 10
# [SAVED] Batch 185 | Records: 10
# [SAVED] Batch 186 | Records: 10
# [SAVED] Batch 187 | Records: 10
# [SAVED] Batch 188 | Records: 10
# [SAVED] Batch 189 | Records: 10
# [SAVED] Batch 190 | Records: 10
# [SAVED] Batch 191 | Records: 10
# [SAVED] Batch 192 | Records: 10
# [SAVED] Batch 193 | Records: 10
# [SAVED] Batch 194 | Records: 10
# [SAVED] Batch 195 | Records: 10
# [SAVED] Batch 196 | Records: 10
# [SAVED] Batch 197 | Records: 10
# [SAVED] Batch 198 | Records: 10
# [SAVED] Batch 199 | Records: 10
# [SAVED] Batch 200 | Records: 10
# [SAVED] Batch 201 | Records: 10
# [SAVED] Batch 202 | Records: 10
# [SAVED] Batch 203 | Records: 10
# [SAVED] Batch 204 | Records: 10
# [SAVED] Batch 205 | Records: 10
# [SAVED] Batch 206 | Records: 10
# [SAVED] Batch 207 | Records: 10
# [SAVED] Batch 208 | Records: 10
# [SAVED] Batch 209 | Records: 10
# [SAVED] Batch 210 | Records: 10
# [SAVED] Batch 211 | Records: 10
# [SAVED] Batch 212 | Records: 10
# [SAVED] Batch 213 | Records: 10
# [SAVED] Batch 214 | Records: 10
# [SAVED] Batch 215 | Records: 10
# [SAVED] Batch 216 | Records: 10
# [SAVED] Batch 217 | Records: 10
# [SAVED] Batch 218 | Records: 10
# [SAVED] Batch 219 | Records: 10
# [SAVED] Batch 220 | Records: 10
# [SAVED] Batch 221 | Records: 10
# [SAVED] Batch 222 | Records: 10
# [SAVED] Batch 223 | Records: 10
# [SAVED] Batch 224 | Records: 10
# [SAVED] Batch 225 | Records: 10
# [SAVED] Batch 226 | Records: 10
# [SAVED] Batch 227 | Records: 10
# [SAVED] Batch 228 | Records: 10
# [SAVED] Batch 229 | Records: 10
# [SAVED] Batch 230 | Records: 10
# [SAVED] Batch 231 | Records: 10
# [SAVED] Batch 232 | Records: 10
# [SAVED] Batch 233 | Records: 10
# [SAVED] Batch 234 | Records: 10
# [SAVED] Batch 235 | Records: 10
# [SAVED] Batch 236 | Records: 10
# [SAVED] Batch 237 | Records: 10
# [SAVED] Batch 238 | Records: 10
# [SAVED] Batch 239 | Records: 10
# [SAVED] Batch 240 | Records: 10
# [SAVED] Batch 241 | Records: 10
# [SAVED] Batch 242 | Records: 10
# [SAVED] Batch 243 | Records: 10
# [SAVED] Batch 244 | Records: 10
# [SAVED] Batch 245 | Records: 10
# [SAVED] Batch 246 | Records: 10
# [SAVED] Batch 247 | Records: 10
# [SAVED] Batch 248 | Records: 10
# [SAVED] Batch 249 | Records: 10
# [SAVED] Batch 250 | Records: 10
# [SAVED] Batch 251 | Records: 10
# [SAVED] Batch 252 | Records: 10
# [SAVED] Batch 253 | Records: 10
# [SAVED] Batch 254 | Records: 10
# [SAVED] Batch 255 | Records: 10
# [SAVED] Batch 256 | Records: 10
# [SAVED] Batch 257 | Records: 10
# [SAVED] Batch 258 | Records: 10
# [SAVED] Batch 259 | Records: 10
# [SAVED] Batch 260 | Records: 10
# [SAVED] Batch 261 | Records: 10
# [SAVED] Batch 262 | Records: 10
# [SAVED] Batch 263 | Records: 10
# [SAVED] Batch 264 | Records: 10
# [SAVED] Batch 265 | Records: 10
# [SAVED] Batch 266 | Records: 10
# [SAVED] Batch 267 | Records: 10
# [SAVED] Batch 268 | Records: 10
# [SAVED] Batch 269 | Records: 10
# [SAVED] Batch 270 | Records: 10
# [SAVED] Batch 271 | Records: 10
# [SAVED] Batch 272 | Records: 10
# [SAVED] Batch 273 | Records: 10
# [SAVED] Batch 274 | Records: 10
# [SAVED] Batch 275 | Records: 10
# [SAVED] Batch 276 | Records: 10
# [SAVED] Batch 277 | Records: 10
# [SAVED] Batch 278 | Records: 10
# [SAVED] Batch 279 | Records: 10
# [SAVED] Batch 280 | Records: 10
# [SAVED] Batch 281 | Records: 10
# [SAVED] Batch 282 | Records: 10
# [SAVED] Batch 283 | Records: 10
# [SAVED] Batch 284 | Records: 10
# [SAVED] Batch 285 | Records: 10
# [SAVED] Batch 286 | Records: 10
# [SAVED] Batch 287 | Records: 10
# [SAVED] Batch 288 | Records: 10
# [SAVED] Batch 289 | Records: 10
# [SAVED] Batch 290 | Records: 10
# [SAVED] Batch 291 | Records: 10
# [SAVED] Batch 292 | Records: 10
# [SAVED] Batch 293 | Records: 10
# [SAVED] Batch 294 | Records: 10
# [SAVED] Batch 295 | Records: 10
# [SAVED] Batch 296 | Records: 10
# [SAVED] Batch 297 | Records: 10
# [SAVED] Batch 298 | Records: 10
# [SAVED] Batch 299 | Records: 10
# [SAVED] Batch 300 | Records: 10
# [SAVED] Batch 301 | Records: 10
# [SAVED] Batch 302 | Records: 10
# [SAVED] Batch 303 | Records: 10
# [SAVED] Batch 304 | Records: 10
# [SAVED] Batch 305 | Records: 10
# [SAVED] Batch 306 | Records: 10
# [SAVED] Batch 307 | Records: 10
# [SAVED] Batch 308 | Records: 10
# [SAVED] Batch 309 | Records: 10
# [SAVED] Batch 310 | Records: 10
# [SAVED] Batch 311 | Records: 10
# [SAVED] Batch 312 | Records: 10
# [SAVED] Batch 313 | Records: 10
# [SAVED] Batch 314 | Records: 10
# [SAVED] Batch 315 | Records: 10
# [SAVED] Batch 316 | Records: 10
# [SAVED] Batch 317 | Records: 10
# [SAVED] Batch 318 | Records: 10
# [SAVED] Batch 319 | Records: 10
# [SAVED] Batch 320 | Records: 10
# [SAVED] Batch 321 | Records: 10
# [SAVED] Batch 322 | Records: 10
# [SAVED] Batch 323 | Records: 10
# [SAVED] Batch 324 | Records: 10
# [SAVED] Batch 325 | Records: 10
# [SAVED] Batch 326 | Records: 10
# [SAVED] Batch 327 | Records: 10
# [SAVED] Batch 328 | Records: 10
# [SAVED] Batch 329 | Records: 10
# [SAVED] Batch 330 | Records: 10
# [SAVED] Batch 331 | Records: 10
# [SAVED] Batch 332 | Records: 10
# [SAVED] Batch 333 | Records: 10
# [SAVED] Batch 334 | Records: 10
# [SAVED] Batch 335 | Records: 10
# [SAVED] Batch 336 | Records: 10
# [SAVED] Batch 337 | Records: 10
# [SAVED] Batch 338 | Records: 10
# [SAVED] Batch 339 | Records: 10
# [SAVED] Batch 340 | Records: 10
# [SAVED] Batch 341 | Records: 10
# [SAVED] Batch 342 | Records: 10
# [SAVED] Batch 343 | Records: 10
# [SAVED] Batch 344 | Records: 10
# [SAVED] Batch 345 | Records: 10
# [SAVED] Batch 346 | Records: 10
# [SAVED] Batch 347 | Records: 10
# [SAVED] Batch 348 | Records: 10
# [SAVED] Batch 349 | Records: 10
# [SAVED] Batch 350 | Records: 10
# [SAVED] Batch 351 | Records: 10
# [SAVED] Batch 352 | Records: 10
# [SAVED] Batch 353 | Records: 10
# [SAVED] Batch 354 | Records: 10
# [SAVED] Batch 355 | Records: 10
# [SAVED] Batch 356 | Records: 10
# [SAVED] Batch 357 | Records: 10
# [SAVED] Batch 358 | Records: 10
# [SAVED] Batch 359 | Records: 10
# [SAVED] Batch 360 | Records: 10
# [SAVED] Batch 361 | Records: 10
# [SAVED] Batch 362 | Records: 10
# [SAVED] Batch 363 | Records: 10
# [SAVED] Batch 364 | Records: 10
# [SAVED] Batch 365 | Records: 10
# [SAVED] Batch 366 | Records: 10
# [SAVED] Batch 367 | Records: 10
# [SAVED] Batch 368 | Records: 10
# [SAVED] Batch 369 | Records: 10
# [SAVED] Batch 370 | Records: 10
# [SAVED] Batch 371 | Records: 10
# [SAVED] Batch 372 | Records: 10
# [SAVED] Batch 373 | Records: 10
# [SAVED] Batch 374 | Records: 10
# [SAVED] Batch 375 | Records: 10
# [SAVED] Batch 376 | Records: 10
# [SAVED] Batch 377 | Records: 10
# [SAVED] Batch 378 | Records: 10
# [SAVED] Batch 379 | Records: 10
# [SAVED] Batch 380 | Records: 10
# [SAVED] Batch 381 | Records: 10
# [SAVED] Batch 382 | Records: 10
# [SAVED] Batch 383 | Records: 10
# [SAVED] Batch 384 | Records: 10
# [SAVED] Batch 385 | Records: 10
# [SAVED] Batch 386 | Records: 10
# [SAVED] Batch 387 | Records: 10
# [SAVED] Batch 388 | Records: 10
# [SAVED] Batch 389 | Records: 10
# [SAVED] Batch 390 | Records: 10
# [SAVED] Batch 391 | Records: 10
# [SAVED] Batch 392 | Records: 10
# [SAVED] Batch 393 | Records: 10
# [SAVED] Batch 394 | Records: 10
# [SAVED] Batch 395 | Records: 10
# [SAVED] Batch 396 | Records: 10
# [SAVED] Batch 397 | Records: 10
# [SAVED] Batch 398 | Records: 10
# [SAVED] Batch 399 | Records: 10
# [SAVED] Batch 400 | Records: 10
# [SAVED] Batch 401 | Records: 10
# [SAVED] Batch 402 | Records: 10
# [SAVED] Batch 403 | Records: 10
# [SAVED] Batch 404 | Records: 10
# [SAVED] Batch 405 | Records: 10
# [SAVED] Batch 406 | Records: 10
# [SAVED] Batch 407 | Records: 10
# [SAVED] Batch 408 | Records: 10
# [SAVED] Batch 409 | Records: 10
# [SAVED] Batch 410 | Records: 10
# [SAVED] Batch 411 | Records: 10
# [SAVED] Batch 412 | Records: 10
# [SAVED] Batch 413 | Records: 10
# [SAVED] Batch 414 | Records: 10
# [SAVED] Batch 415 | Records: 10
# [SAVED] Batch 416 | Records: 10
# [SAVED] Batch 417 | Records: 10
# [SAVED] Batch 418 | Records: 10
# [SAVED] Batch 419 | Records: 10
# [SAVED] Batch 420 | Records: 10
# [SAVED] Batch 421 | Records: 10
# [SAVED] Batch 422 | Records: 10
# [SAVED] Batch 423 | Records: 10
# [SAVED] Batch 424 | Records: 10
# [SAVED] Batch 425 | Records: 10
# [SAVED] Batch 426 | Records: 10
# [SAVED] Batch 427 | Records: 10
# [SAVED] Batch 428 | Records: 10
# [SAVED] Batch 429 | Records: 10
# [SAVED] Batch 430 | Records: 10
# [SAVED] Batch 431 | Records: 10
# [SAVED] Batch 432 | Records: 10
# [SAVED] Batch 433 | Records: 10
# [SAVED] Batch 434 | Records: 10
# [SAVED] Batch 435 | Records: 10
# [SAVED] Batch 436 | Records: 10
# [SAVED] Batch 437 | Records: 10
# [SAVED] Batch 438 | Records: 10
# [SAVED] Batch 439 | Records: 10
# [SAVED] Batch 440 | Records: 10
# [SAVED] Batch 441 | Records: 10
# [SAVED] Batch 442 | Records: 10
# [SAVED] Batch 443 | Records: 10
# [SAVED] Batch 444 | Records: 10
# [SAVED] Batch 445 | Records: 10
# [SAVED] Batch 446 | Records: 10
# [SAVED] Batch 447 | Records: 10
# [SAVED] Batch 448 | Records: 10
# [SAVED] Batch 449 | Records: 10
# [SAVED] Batch 450 | Records: 10
# [SAVED] Batch 451 | Records: 10
# [SAVED] Batch 452 | Records: 10
# [SAVED] Batch 453 | Records: 10
# [SAVED] Batch 454 | Records: 10
# [SAVED] Batch 455 | Records: 10
# [SAVED] Batch 456 | Records: 10
# [SAVED] Batch 457 | Records: 10
# [SAVED] Batch 458 | Records: 10
# [SAVED] Batch 459 | Records: 10
# [SAVED] Batch 460 | Records: 10
# [SAVED] Batch 461 | Records: 10
# [SAVED] Batch 462 | Records: 10
# [SAVED] Batch 463 | Records: 10
# [SAVED] Batch 464 | Records: 10
# [SAVED] Batch 465 | Records: 10
# [SAVED] Batch 466 | Records: 10
# [SAVED] Batch 467 | Records: 10
# [SAVED] Batch 468 | Records: 10
# [SAVED] Batch 469 | Records: 10
# [SAVED] Batch 470 | Records: 10
# [SAVED] Batch 471 | Records: 10
# [SAVED] Batch 472 | Records: 10
# [SAVED] Batch 473 | Records: 10
# [SAVED] Batch 474 | Records: 10
# [SAVED] Batch 475 | Records: 10
# [SAVED] Batch 476 | Records: 10
# [SAVED] Batch 477 | Records: 10
# [SAVED] Batch 478 | Records: 10
# [SAVED] Batch 479 | Records: 10
# [SAVED] Batch 480 | Records: 10
# [SAVED] Batch 481 | Records: 10
# [SAVED] Batch 482 | Records: 10
# [SAVED] Batch 483 | Records: 10
# [SAVED] Batch 484 | Records: 10
# [SAVED] Batch 485 | Records: 10
# [SAVED] Batch 486 | Records: 10
# [SAVED] Batch 487 | Records: 10
# [SAVED] Batch 488 | Records: 10
# [SAVED] Batch 489 | Records: 10
# [SAVED] Batch 490 | Records: 10
# [SAVED] Batch 491 | Records: 10
# [SAVED] Batch 492 | Records: 10
# [SAVED] Batch 493 | Records: 10
# [SAVED] Batch 494 | Records: 10
# [SAVED] Batch 495 | Records: 10
# [SAVED] Batch 496 | Records: 10
# [SAVED] Batch 497 | Records: 10
# [SAVED] Batch 498 | Records: 10
# [SAVED] Batch 499 | Records: 10
# [INFO] Ingestion complete. Total records saved: 5000
# [MANIFEST] Created: stream_manifest.json
# Extended streaming simulation complete.
